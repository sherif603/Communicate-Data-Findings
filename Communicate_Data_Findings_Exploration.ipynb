# %% [markdown]
# <h1><center> Communication Data Findings Project</center></h1>
#
# The **Communication Data Findings Project** as a part of the **Udacity Adanced Data Analyst Nano-Degree Program** is focusing on **exploratory data visualization** and **explanatory data visualization**.
#
# By `Sherif Sakr`
#
# `Cairo, Egypt`

# %% [markdown]
# **Dataset**
#
# - This document explores the Ford GoBike's trip data for public containing bike rides from April FY2019.
# - The attributes included the trip start/end time, as well as additional measurements such as user type, gender, and age.
# - 16K data points were removed from the analysis due to missing values in some fields, data inconsistent, or outliner issues.

# %% [markdown]
# **Bay Wheels Bike Sharing System, Ford GoBike**
#
# `Bay Wheels` is a regional public `bicycle sharing system` in `San Francisco Bay Area`, `California`. It is operated by Motivate in a partnership with the Metropolitan Transportation Commission and the Bay Area Air Quality Management District. Bay Wheels is the first regional and large-scale bicycle sharing system deployed in California and on the West Coast of the United States. It was established as Bay Area Bike Share in August 2013. As of January 2018, the Bay Wheels system had over 2,600 bicycles in 262 stations across San Francisco, East Bay and San Jose.
#
# However, in June 2017 the system was officially re-launched as `Ford GoBike` in a partnership with Ford Motor Company. After Motivate's acquisition by Lyft, the system was renamed to Bay Wheels in June 2019.

# %% [markdown]
# **Exploratory vs. Explanatory analyses**
#
# **Exploratory analysis** is what you do to get familiar with the data. You may start out with a hypothesis or question, or you may just really be delving into the data to determine what might be interesting about it. Exploratory analysis is the process of turning over 100 rocks to find perhaps 1 or 2 precious gemstones.
#
# Exploratory analysis is done for searching for insights, looking for relationship in the data, connect to questions about data, and visualizations do not need to be perfect.
#
# Exploratory data visualization generally occurs during and after the data wrangling process, and is the main method that you will use to understand the patterns and relationships present in your data. This understanding will help you approach any statistical analyses and will help you build conclusions and findings. This process might also illuminate additional data cleaning tasks to be performed.
#
# **Explanatory analysis** is what happens when you have something specific you want to show an audience - probably about those 1 or 2 precious gemstones. In my blogging and writing, I tend to focus mostly on this latter piece, explanatory analysis, when you've already gone through the exploratory analysis and from this have determined something specific you want to communicate to a given audience: in other words, when you want to tell a story with data.
#
# Explanatory analysis is done when providing the results for others, and to highlight insight, surrounded by a story, and do not include unneeded information.
#
# Explanatory data visualization techniques are used after generating your findings, and are used to help communicate your results to others. Understanding design considerations will make sure that your message is clear and effective. In addition to being a good producer of visualizations, going through this project will also help you be a good consumer of visualizations that are presented to you by others.

# %% [markdown]
# **Quantitative Data vs. Qualitative Data**
#
# - Quantitative data is the data that is measured in numbers. It deals with numbers that make sense to perform arithmetic calculation with. It consists of discrete variables and continuous variables.
#
# - Qualitative data or categorical data referes to the values that place 'things' into different groups or categories.It consists of ordinal variables and nominal variables.

# %% [markdown]
# **Python Data Visualization Libraries**
#
# - Matplotlib
#
# A versatile library for visualization, but it can take some code effect to put together common visualizations.
#
# - Seaborn
#
# Built on top of Matplotlib, adds a number of functions to make common statistical visualizations easier to generate.
#
# - Pandas
#
# While this library includes some convenient methods for visualizating data that hook into Matplotlib, It mainly be used for its main purpose as a general tool for working with data.
#
# - All Python Data Visualization Libraries together will allow you to visualize data in a balance of productivity and flexibility, for both exploratory as well as explanatory analyses.

# %%
# Load Modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import random
import os
import glob
# %matplotlib inline
from matplotlib import rcParams

# %% [markdown]
# <h3><center>wrangling data (data gathering, data assessing, and data cleaning)</center></h3>

# %%
# Load 2021_01_28_fordgobike_tripdata.csv data and store it in the DataFrame.
# Use pandas.read_csv() function to read a comma-separated values(csv) file into DataFrame.
df1 = pd.read_csv('2021_01_28_fordgobike_tripdata.csv')

# Use pandas.DataFrame.shape function to return a tuple representing the dimensionality of the DataFrame
print(df1.shape)

# Use a pandas.DataFrame.head(n=5) function to return the first numbers of rows for the object based on position.
df1.head()
# Out:
# (183412, 16)
#    duration_sec                start_time                  end_time  \
# 0         52185  2019-02-28 17:32:10.1450  2019-03-01 08:01:55.9750
# 1         42521  2019-02-28 18:53:21.7890  2019-03-01 06:42:03.0560
# 2         61854  2019-02-28 12:13:13.2180  2019-03-01 05:24:08.1460
# 3         36490  2019-02-28 17:54:26.0100  2019-03-01 04:02:36.8420
# 4          1585  2019-02-28 23:54:18.5490  2019-03-01 00:20:44.0740
#
#    start_station_id                                start_station_name  \
# 0              21.0  Montgomery St BART Station (Market St at 2nd St)
# 1              23.0                     The Embarcadero at Steuart St
# 2              86.0                           Market St at Dolores St
# 3             375.0                           Grove St at Masonic Ave
# 4               7.0                               Frank H Ogawa Plaza
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# ...

# %%
# Use pandas.DataFrame.dtypes function to return the data types in the DataFrame
print(df1.dtypes)
# Out:
# duration_sec                 int64
# start_time                  object
# end_time                    object
# start_station_id           float64
# start_station_name          object
# start_station_latitude     float64
# start_station_longitude    float64
# end_station_id             float64
# end_station_name            object
# end_station_latitude       float64
# end_station_longitude      float64
# bike_id                      int64
# user_type                   object
# member_birth_year          float64
# member_gender               object
# bike_share_for_all_trip     object
# dtype: object

# %%
# Use pandas DataFrame.iloc[] for integer-location based indexing for selection by position
df1.iloc[0]
# Out:
# duration_sec                                                          52185
# start_time                                         2019-02-28 17:32:10.1450
# end_time                                           2019-03-01 08:01:55.9750
# start_station_id                                                         21
# start_station_name         Montgomery St BART Station (Market St at 2nd St)
# start_station_latitude                                              37.7896
# start_station_longitude                                            -122.401
# end_station_id                                                           13
# end_station_name                             Commercial St at Montgomery St
# end_station_latitude                                                37.7942
# end_station_longitude                                              -122.403
# bike_id                                                                4902
# ...

# %%
# Use pandas.DataFrame.ndim to return an integer representing the number of axes/ array dimensions.
df1.ndim
# Out:
# 2

# %%
# Use pandas.DataFrame.size to return an integer representing the number of elements in the object.
# It returns the number of rows if Series. Otherwise, it returns the number of rows times number of columns if DataFrame.
df1.size
# Out:
# 2934592

# %%
# Use a Python built-in function list() to return a list in Python (the column names in pandas.DataFrame)
list(df1)
# Out:
# ['duration_sec',
#  'start_time',
#  'end_time',
#  'start_station_id',
#  'start_station_name',
#  'start_station_latitude',
#  'start_station_longitude',
#  'end_station_id',
#  'end_station_name',
#  'end_station_latitude',
#  'end_station_longitude',
#  'bike_id',
#  'user_type',
#  'member_birth_year',
#  'member_gender',
#  'bike_share_for_all_trip']

# %%
# Use pandas.DataFrame.isnull() method to detect the Null values or missing values.
df1.isnull().any()
# Out:
# duration_sec               False
# start_time                 False
# end_time                   False
# start_station_id            True
# start_station_name          True
# start_station_latitude     False
# start_station_longitude    False
# end_station_id              True
# end_station_name            True
# end_station_latitude       False
# end_station_longitude      False
# bike_id                    False
# user_type                  False
# member_birth_year           True
# member_gender               True
# bike_share_for_all_trip    False
# dtype: bool

# %%
# Use pandas.DataFrame.value_counts() function to return a Series containing counts of unique rows in the DataFrame
df1.user_type.value_counts()
# Out:
# Subscriber    163544
# Customer       19868
# Name: user_type, dtype: int64

# %%
# Use pandas.value_counts(normalize=True) function to return a Series containing the relative frequencies of the unique values. 
df1.user_type.value_counts(normalize=True)
# Out:
# Subscriber    0.891676
# Customer      0.108324
# Name: user_type, dtype: float64

# %%
# Use pandas.DataFrame.value_counts() function to return a Series containing counts of unique rows in the DataFrame
df1.member_gender.value_counts()
# Out:
# Male      130651
# Female     40844
# Other       3652
# Name: member_gender, dtype: int64

# %%
# Use pandas.value_counts(normalize=True) function to return a Series containing the relative frequencies of the unique values. 
df1.member_gender.value_counts(normalize=True)
# Out:
# Male      0.745951
# Female    0.233198
# Other     0.020851
# Name: member_gender, dtype: float64

# %%
# Use pandas.DataFrame.value_counts() function to return a Series containing counts of unique rows in the DataFrame
df1.bike_share_for_all_trip.value_counts()
# Out:
# No     166053
# Yes     17359
# Name: bike_share_for_all_trip, dtype: int64

# %%
# Use pandas.value_counts(normalize=True) function to return a Series containing the relative frequencies of the unique values. 
df1.bike_share_for_all_trip.value_counts(normalize=True)
# Out:
# No     0.905355
# Yes    0.094645
# Name: bike_share_for_all_trip, dtype: float64

# %%
# Use pandas.DataFrame.info() to Print a concise summary of a DataFrame, including the index dtype and columns, 
# non-null values, and memory usage.
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183412 entries, 0 to 183411
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             183412 non-null  int64
#  1   start_time               183412 non-null  object
#  2   end_time                 183412 non-null  object
#  3   start_station_id         183215 non-null  float64
#  4   start_station_name       183215 non-null  object
#  5   start_station_latitude   183412 non-null  float64
#  6   start_station_longitude  183412 non-null  float64
#  7   end_station_id           183215 non-null  float64
#  8   end_station_name         183215 non-null  object
#  9   end_station_latitude     183412 non-null  float64
#  10  end_station_longitude    183412 non-null  float64
#  11  bike_id                  183412 non-null  int64
#  12  user_type                183412 non-null  object
# ...

# %% [markdown]
# #### Cleaning Data

# %%
# Create copies of the two DataFrames for Cleaning purposes:
df = df1.copy()

# %%
# Use pandas.DataFrame.duplicated() function to return boolean Series denoting duplicate rows
df.duplicated().sum()
# Out:
# 0

# %%
# Use pandas.DataFrame.isnull() method to detect the Null values or missing values, and sum the numbers of missing values
print('The number of rows have missing value {}.'.format(sum(df.isnull().any())))
# Out:
# The number of rows have missing value 6.

# %%
# Use DataFrame.dropna() function to drop (remove) missing values.
df.dropna(inplace=True)

# %%
# Use pandas.DataFrame.isnull() method to detect the Null values or missing values, and sum the numbers of missing values
print('The number of rows have missing value {}.'.format(sum(df.isnull().any())))
# Out:
# The number of rows have missing value 0.

# %%
# Use pandas.to_datetime() function to convert arguments in start_time and end_time columns into datetime
df.start_time = pd.to_datetime(df.start_time)
df.end_time = pd.to_datetime(df.end_time)

# %%
# Use pandas.DataFrame.astype() function to cast a pandas object to a specified data type
df['start_station_id'] = df['start_station_id'].astype('str')
df['end_station_id'] = df['end_station_id'].astype('str')

# %%
# Use pandas.DataFrame.astype() function to cast a pandas object to a specified data type
df['user_type'] = df['user_type'].astype('category')
df['member_gender'] = df['member_gender'].astype('category')

# %%
# Create new column 'member_age'
df['member_age'] = 2021 - df['member_birth_year']
df[['member_birth_year', 'member_age']]
# Out:
#         member_birth_year  member_age
# 0                  1984.0        37.0
# 2                  1972.0        49.0
# 3                  1989.0        32.0
# 4                  1974.0        47.0
# 5                  1959.0        62.0
# ...                   ...         ...
# 183407             1996.0        25.0
# 183408             1984.0        37.0
# 183409             1990.0        31.0
# 183410             1988.0        33.0
# 183411             1989.0        32.0
#
# [174952 rows x 2 columns]

# %%
# Extract day of week, and hours information from the start_time
# Use pandas.Series.dt.dayofweek() function to extract the day of the week with Monday=0, Sunday=6.
# Use pandas.Series.dt.hour method to extract the hours of the datetime.

df['start_time_dayofweek']= df['start_time'].dt.strftime('%a')
df['start_time_hour']= df['start_time'].dt.hour

# %%
df[['start_time_dayofweek','start_time_hour']]
# Out:
#        start_time_dayofweek  start_time_hour
# 0                       Thu               17
# 2                       Thu               12
# 3                       Thu               17
# 4                       Thu               23
# 5                       Thu               23
# ...                     ...              ...
# 183407                  Fri                0
# 183408                  Fri                0
# 183409                  Fri                0
# 183410                  Fri                0
# 183411                  Fri                0
#
# [174952 rows x 2 columns]

# %%
# Use pandas.DataFrame.info() to Print a concise summary of a DataFrame, including the index dtype and columns, 
# non-null values, and memory usage.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 174952 entries, 0 to 183411
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             174952 non-null  int64
#  1   start_time               174952 non-null  datetime64[ns]
#  2   end_time                 174952 non-null  datetime64[ns]
#  3   start_station_id         174952 non-null  object
#  4   start_station_name       174952 non-null  object
#  5   start_station_latitude   174952 non-null  float64
#  6   start_station_longitude  174952 non-null  float64
#  7   end_station_id           174952 non-null  object
#  8   end_station_name         174952 non-null  object
#  9   end_station_latitude     174952 non-null  float64
#  10  end_station_longitude    174952 non-null  float64
#  11  bike_id                  174952 non-null  int64
#  12  user_type                174952 non-null  category
# ...

# %%
# Use pandas.DataFrame.value_counts() function to return a Series containing counts of unique rows in the DataFrame
df.start_time_dayofweek.value_counts()
# Out:
# Thu    33712
# Tue    30584
# Wed    28426
# Fri    27663
# Mon    25641
# Sun    14512
# Sat    14414
# Name: start_time_dayofweek, dtype: int64

# %%
# Use pandas.value_counts(normalize=True) function to return a Series containing the relative frequencies of the unique values. 
df.start_time_dayofweek.value_counts(normalize=True)
# Out:
# Thu    0.192693
# Tue    0.174814
# Wed    0.162479
# Fri    0.158118
# Mon    0.146560
# Sun    0.082948
# Sat    0.082388
# Name: start_time_dayofweek, dtype: float64

# %%
# Convert the start_time_dayofweek to ordinal variables.
weekdays = ['Mon','Tue','Wed','Thu','Fri', 'Sat', 'Sun']
ordered_weekdays = pd.api.types.CategoricalDtype(ordered = True, categories = weekdays)
df['start_time_dayofweek'] = df['start_time_dayofweek'].astype(ordered_weekdays)

# %%
# Extract 'duration_minutes' column from 'duration_second' column
df['duration_min'] = df['duration_sec'] /60

# %%
df[['duration_sec', 'duration_min']]
# Out:
#         duration_sec  duration_min
# 0              52185    869.750000
# 2              61854   1030.900000
# 3              36490    608.166667
# 4               1585     26.416667
# 5               1793     29.883333
# ...              ...           ...
# 183407           480      8.000000
# 183408           313      5.216667
# 183409           141      2.350000
# 183410           139      2.316667
# 183411           271      4.516667
#
# [174952 rows x 2 columns]

# %%
# Use pandas.DataFrame.describe() function to generate descriptive statistics
df.describe()
# Out:
#         duration_sec  start_station_latitude  start_station_longitude  \
# count  174952.000000           174952.000000            174952.000000
# mean      704.002744               37.771220              -122.351760
# std      1642.204905                0.100391                 0.117732
# min        61.000000               37.317298              -122.453704
# 25%       323.000000               37.770407              -122.411901
# 50%       510.000000               37.780760              -122.398279
# 75%       789.000000               37.797320              -122.283093
# max     84548.000000               37.880222              -121.874119
#
#        end_station_latitude  end_station_longitude        bike_id  \
# count         174952.000000          174952.000000  174952.000000
# mean              37.771414            -122.351335    4482.587555
# std                0.100295               0.117294    1659.195937
# min               37.317298            -122.453704      11.000000
# ...

# %%
# Use mean() function to calculate an arithmetic mean or average of data
df['member_age'].mean()
# Out:
# 36.196865425945404

# %%
# Save Cleaned Data
# df1.to_csv('df.csv', index=False)

# %% [markdown]
# **What is the structure of the dataset?**
#
# The structure of the Ford Go Bike dataset contain approximately 183412 rows (observation) and 16 columns (variables),
# and the variables (features) can be divided into three main categories.
#
# 1- trip duration:
# - duration_sec,
# - duration_min (numerical variable)
# - start_time,
# - end_time
# - start_time_dayofweek (categorical variable),
# - start_time_hour (categorical variable).
#
# 2- station info:
# - start_station_id,
# - start_station_name,
# - start_station_latitude,
# - start_station_longitude,
# - end_station_id,
# - end_station_name,
# - end_station_latitude,
# - end_station_longitude.
#
# 3- member info:
# - bike_id,
# - user_type (categorical variable),
# - member_birth_year (numerical variable),
# - member_gender (numerical variable),
# - bike_share_for_all_trip (categorical variable)
# - member_age (numerical variable)
#
# There are nine numerical data, two date time, four object type, and one boolean type.

# %% [markdown]
# **What is/are the main feature(s) of interest in your dataset?**
#
# I'm most interested in figuring out how trip duration is dependent on other features such as age, start station, end station, user type, and gender.

# %% [markdown]
# **What features in the dataset do you think will help support your investigation into your feature(s) of interest?**
#
# - I expect that trip duration will have the strongest effect on each the start stations and end stations becouse the crowded places should receive more rides.
#
# - I also think that user_type, age, and gender will have effects on trip duration.
#
# - I may also that start time, and end time will have effects on trip duration.

# %% [markdown]
# <h3><center> Univariate Exploration</center></h3>

# %%
# The color_palette() returns the the current / default palette as a list of RGB tuples. 
# Each tuple consists of three digits specifying the red, green, and blue channel values to specify a color. 
# Choose the first tuple of RGB colors
sb.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
# Save a palette to a variable
palette = sb.color_palette('bright')
# Use palplot and pass in the variable
sb.palplot(palette)

# %%
# Use 'tab10', These colors have the same ordering as the default matplotlib color palette,but they are a bit less intense.
sb.color_palette("tab10")
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sb.color_palette("Paired")
# Out:
# [(0.6509803921568628, 0.807843137254902, 0.8901960784313725),
#  (0.12156862745098039, 0.47058823529411764, 0.7058823529411765),
#  (0.6980392156862745, 0.8745098039215686, 0.5411764705882353),
#  (0.2, 0.6274509803921569, 0.17254901960784313),
#  (0.984313725490196, 0.6039215686274509, 0.6),
#  (0.8901960784313725, 0.10196078431372549, 0.10980392156862745),
#  (0.9921568627450981, 0.7490196078431373, 0.43529411764705883),
#  (1.0, 0.4980392156862745, 0.0),
#  (0.792156862745098, 0.6980392156862745, 0.8392156862745098),
#  (0.41568627450980394, 0.23921568627450981, 0.6039215686274509),
#  (1.0, 1.0, 0.6),
#  (0.6941176470588235, 0.34901960784313724, 0.1568627450980392)]

# %% [markdown]
# **Resources:**
#
# - Udacity Classroom, Lesson 3: Univariate Exploration of Data.
#
# - Use the documentation [Website](seaborn.pydata.org/tutorial/color_palettes.html), `General principles for using color in plots`, and the `componets of color`.
#
# - Use the documentation [Website](https://www.codecademy.com/articles/seaborn-design-ii), `Commands for Working with Palettes`.

# %% [markdown]
# #### Plotting 'start_time_hour' feature

# %%
# The distribution of the trip duration over day hours
# Use seaborn.color_palette() function to return a list of color or continuous colormap defining a palette.
base_color = sb.color_palette('colorblind')[0]
# Use seaborn.set_style() function to set aesthetic style of the plots
sb.set_style('darkgrid')
# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27])
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('Distribution of Trip Duration over day hours')
# Use seaborn.countplot() function to show the counts of observations in each categorical bin using bars.
sb.countplot(data=df, x='start_time_hour', color=base_color);
# Use matplotlib.pyplot.xlabel to set the label for the x-axis.
plt.xlabel('Trip Start Hour of Day');
# Use matplotlib.pyplot.ylabel to set the label for the y-axis.
plt.ylabel('Count');

# %% [markdown]
# **Observation**
#
# - From the start time hour, the time 8:00 AM and 5:00 PM are the two peak hours which have most bikers, followed by 9:00 AM and 6:00 PM.

# %% [markdown]
# #### Plotting 'start_time_dayofweek' feature

# %%
df['start_time_dayofweek'].value_counts()
# Out:
# Thu    33712
# Tue    30584
# Wed    28426
# Fri    27663
# Mon    25641
# Sun    14512
# Sat    14414
# Name: start_time_dayofweek, dtype: int64

# %%
# Duratuion Trip over the day of the week
# Use seaborn.color_palette() function to return a list of color or continuous colormap defining a palette.
default_color = sb.color_palette()[0]
dayofweek_order = df['start_time_dayofweek'].value_counts().index
# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27])
# Use seaborn.countplot()** function to show the counts of observations in each categorical bin using bars.
sb.countplot(data = df, x = 'start_time_dayofweek', color = default_color, order=dayofweek_order);
# Use matplotlib.pyplot.title to set a title for the axes.
plt.title('Frequency in Start Time, Day of Week');
# Use matplotlib.pyplot.xlabel to set the label for the x-axis.
plt.xlabel('Start Time, Day of Week');

# %% [markdown]
# **Observation**
#
# - Thursday has the most bikers with counts of 33,712 of unique values compared to other days.
# - However, Saturday has the lowest number of bikers with counts of 14,414 of unique values.

# %%
df['user_type'].value_counts()
# Out:
# Subscriber    158386
# Customer       16566
# Name: user_type, dtype: int64

# %%
df['user_type'].value_counts(normalize=True)
# Out:
# Subscriber    0.905311
# Customer      0.094689
# Name: user_type, dtype: float64

# %%
# count plot on single categorical variable

# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27])
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('Distribution of Customer vs. Subscriber')
# Use seaborn.countplot()** function to show the counts of observations in each categorical bin using bars.
sb.countplot(x ='user_type',hue='user_type', data = df)
# Use matplotlib.pyplot.show() function to display all figures. 
plt.show();

# %% [markdown]
# **Observation**
#
# - The subscriber has the highest number 158,386 of the unique values of the user type.
# - The customer has the lowest numver 16,566 of the unique values of the user type.
# - The subscriber and customer are representing approximately 90% and 10% of the user type, repectively.

# %%
# count plot on single categorical variable

# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27])
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('Distribution of Customer vs. Subscriber')
# Use seaborn.countplot()** function to show the counts of observations in each categorical bin using bars.
# count plot along y axis
sb.countplot(y ='user_type', hue='user_type', data = df)
# Use matplotlib.pyplot.show() function to display all figures. 
plt.show();

# %% [markdown]
# **Observation**
#
# - The subscriber has the highest number 158,386 of the unique values of the user type.
# - The customer has the lowest numver 16,566 of the unique values of the user type.
# - The subscriber and customer are representing approximately 90% and 10% of the user type, repectively.

# %%
# count plot on single categorical variable

# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27])
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('Distribution of Customer vs. Subscriber')
# Use seaborn.countplot()** function to show the counts of observations in each categorical bin using bars.
sb.countplot(x ='user_type', data = df, color="salmon", facecolor=(0,0,0,0), linewidth=5, edgecolor=sb.color_palette('BrBG',2))
# Use matplotlib.pyplot.show() function to display all figures. 
plt.show();

# %% [markdown]
# **Observation**
#
# - The subscriber has the highest number 158,386 of the unique values of the user type.
# - The customer has the lowest numver 16,566 of the unique values of the user type.
# - The subscriber and customer are representing approximately 90% and 10% of the user type, repectively.

# %% [markdown]
# **Resources:**
#
# - Udacity Classroom, Lesson 3: Univariate Exploration of Data.
#
# - Use the documentation [Website](https://seaborn.pydata.org/generated/seaborn.countplot.html?highlight=seaborn%20countplot#seaborn.countplot), Use **seaborn.countplot()** function to show the counts of observations in each categorical bin using bars.
#
# - Use the documentation [Website](https://www.geeksforgeeks.org/countplot-using-seaborn-in-python/), Use a different color palette in count plot, and use matplotlib.axes.Axes.bar() parameters to control the style.
#
# - Use the documentation [Website](https://stackoverflow.com/questions/33179122/seaborn-countplot-with-frequencies), Use seaborn.countplot() function with frequencies.
#
# - Use the documentation [Website](https://towardsdatascience.com/hands-on-python-data-visualization-seaborn-count-plot-90e823599012) Create a simple count plot for a single categorical variable.

# %%
# the Distribution of Start Time, Day of week
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
sorted_counts = df['start_time_dayofweek'].value_counts()
# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27])
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('Distribution of Start Time During the Days of the Week')
# Use matplotlib.pyplot.pie() function to plot a pie chart
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90, counterclock = False, autopct='%1.1f%%');
# Use matplotlib.pyplot.axis('square') to create a square plot with equal axes
plt.axis('square');

# %% [markdown]
# **Observation**
#
# - From the days of the week, Thursday has the most bikers, compared to other days, with a percentage of 19.3%.
# - However, Saturday has the lowest number of bikers, with a percentage of 8.2%.

# %%
# the Distribution of Start Time, Day of week
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
sorted_counts = df['start_time_dayofweek'].value_counts()
# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27])
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('Distribution of Start Time During the Days of the Week')
# Use matplotlib.pyplot.pie() function to plot a pie chart
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90, counterclock = False, autopct='%1.1f%%');
# Use matplotlib.pyplot.axis('square') to create a square plot with equal axes
plt.axis('square');
# Use matplotlib.pyplot.legend() function to place a legend on the axes 
plt.legend(title ="Day of Week",loc ="upper left",bbox_to_anchor =(1, 0, 0.5, 1));  
# Use matplotlib.pyplot.show() function to display all figures. 
plt.show();

# %% [markdown]
# **Observation**
#
# - From the days of the week, Thursday has the most bikers, compared to other days, with a percentage of 19.3%.
# - However, Saturday has the lowest number of bikers, with a percentage of 8.2%.

# %% [markdown]
# **Resources:**
#
# - Udacity Classroom, Lesson 3: Univariate Exploration of Data.
#
# - Use the documentation [Website](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.pie.html?highlight=pie#matplotlib.pyplot.pie), Use **matplotlib.pyplot.pie()** function to plot a pie chart.
#
# - Use the documentation [Website](https://www.geeksforgeeks.org/plot-a-pie-chart-in-python-using-matplotlib/), Plot a pie chart in Python using Matplotlib.
#
# - Use the documentation [Website](https://www.tutorialspoint.com/matplotlib/matplotlib_pie_chart.htm), matplotlib - Pie chart.

# %% [markdown]
# **Donut Plot**
#
# - A sister plot to the pie chart is the donut plot. It's just like a pie chart, except that there's a hole in the center of the plot. Perceptually, there's not much difference between a donut plot and a pie chart, and donut plots should be used with the same guidelines as a pie chart. Aesthetics might be one of the reasons why you would choose one or the other. For instance, you might see statistics reported in the hole of a donut plot to better make use of available space.
#
# - To create a donut plot, you can add a wedgeprops argument to the pie function call. By default, the radius of the pie (circle) is 1; setting the wedges' width property to less than 1 removes coloring from the center of the circle.

# %%
sorted_counts = df['start_time_dayofweek'].value_counts()
# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27])
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('Distribution of Start Time During the Days of the Week')
# Use matplotlib.pyplot.pie() function to plot a pie chart, with this parameters to create the donut plot.
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90, counterclock = False, wedgeprops = {'width' : 0.4});
# Use matplotlib.pyplot.axis('square') to create a square plot with equal axes
plt.axis('square');
# Use matplotlib.pyplot.legend() function to place a legend on the axes 
plt.legend(title ="Day of Week",loc ="upper left",bbox_to_anchor =(1, 0, 0.5, 1));  
# Use matplotlib.pyplot.show() function to display all figures. 
plt.show();

# %% [markdown]
# **Observation**
#
# From the days of the week, Thursday has the most bikers, compared to other days.

# %% [markdown]
# **Resources:**
#
# - Udacity Classroom, Lesson 3: Univariate Exploration of Data.
#
# - Use the documentation [Website](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.pie.html?highlight=pie#matplotlib.pyplot.pie), Use **matplotlib.pyplot.pie()** function to plot a pie chart (Donut Plot).
#
# - Use the documentation [Website](https://python-graph-gallery.com/donut-plot/), Plot a Pie chart (Donut plot) in Python using Matplotlib, A Python Graph Gallery.
#
# - Use the documentation [Website](https://medium.com/@kvnamipara/a-better-visualisation-of-pie-charts-by-matplotlib-935b7667d77f), A better visualization of pie charts by matplotlib.

# %% [markdown]
# #### Plotting 'duration_min' feature

# %%
df[['duration_sec','duration_min']].describe()
# Out:
#         duration_sec   duration_min
# count  174952.000000  174952.000000
# mean      704.002744      11.733379
# std      1642.204905      27.370082
# min        61.000000       1.016667
# 25%       323.000000       5.383333
# 50%       510.000000       8.500000
# 75%       789.000000      13.150000
# max     84548.000000    1409.133333

# %% [markdown]
# **Histogram**
#
# - A `Histogram` is used to plot the distribution of a numeric varible. It is the quantitative version of bar chart.
# - However, rather than plot one bar for each unique numberic value, values are grouped into continuous bins, and one bar for each bin is plotted to depict the number.
# - A `histogram` tells you how many observations or data points fall in various ranges of values.
# - Use `Matplotlib.pyplot.hist()` function to create `histograms`.
# - However, a `histogram` shows the frequency on the vertical axis and the horizontal axis is another dimension. Usually it has bins, where every bin has a minimum and maximum value. Each bin also has a frequency between x and infinite.

# %%
# The Distribution of Trip Duration, in Minutes

# Set the bins, where the bin has a minimum value and maximum value.
bins = np.arange(0, df['duration_min'].max()+10, 10)
# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27])
# Use matplotlib.pyplot.hist() function to plot a histogram.
plt.hist(data = df, x = 'duration_min', bins = bins)
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('Distribution of Trip Durations')
# Use matplotlib.pyplot.xlabel to set the label for the x-axis.
plt.xlabel('Duration_min')
# Use matplotlib.pyplot.ylabel to set the label for the y-axis.
plt.ylabel('Number of Trips')
# Use matplotlib.pyplot.xlim() function to get or set the x limits of the current axes.
plt.xlim((0,200));
# Use matplotlib.pyplot.show () function to display all open figures.
plt.show();

# %% [markdown]
# **Observation**
#
# - The distribution of Trip duration is between 1 and 60 minutes,and with peak around 20 minutes.

# %% [markdown]
# **Resources:**
#
# - Udacity Classroom, Lesson 3: Univariate Exploration of Data, 8.Histograms.
#
# - Use the documentation [Website](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.hist.html?highlight=hist#matplotlib.pyplot.hist), Use **matplotlib.pyplot.hist()** function to plot a histogram.
#
# - Use the documentation [Website](https://www.geeksforgeeks.org/matplotlib-pyplot-hist-in-python/), Matplotlib.pyplot.hist() in Python.
#
# - Use the documentation [Website](https://stackoverflow.com/questions/6986986/bin-size-in-matplotlib-histogram), Bin size in Matplotlib (Histogram).

# %% [markdown]
# **Bell-shape Curve**
#
# - A bell curve is a common type of distribution for a variable, also known as the normal distribution.
# - The term "bell curve" originates from the fact that the graph used to depict a normal distribution consists of a symmetrical bell-shaped curve.
# - The highest point on the curve, or the top of the bell, represents the most probable event in a series of data (its mean, mode, and median in this case), while all other possible occurrences are symmetrically distributed around the mean, creating a downward-sloping curve on each side of the peak. The width of the bell curve is described by its standard deviation.
# - A bell curve is a graph depicting the normal distribution, which has a shape reminiscent of a bell.
# - The top of the curve shows the mean, mode, and median of the data collected.
# - Its standard deviation depicts the bell curve's relative width around the mean.

# %%
# Plot two histograms side-by-side by using matplotlib.pyplot.subplot() function
# Resize the chart, and have two plots side-by-side
# Set a larger figure size for subplots
plt.figure(figsize = [10, 5]) 

# Use matplotlib.pyplot.subplot() function to add a subplot to the current figure.
# histogram on left, example of too-large bin size
# 1 row, 2 cols, subplot 1
plt.subplot(1, 2, 1) 
bins = np.arange(0, df['duration_min'].max()+10, 10)
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('Distribution of Trip Duration In Minutes')
plt.hist(data = df, x = 'duration_min', bins = bins);
plt.xlim((0,200));

# histogram on right, example of too-small bin size
# 1 row, 2 cols, subplot 2
plt.subplot(1, 2, 2) 
bins = np.arange(0, df['duration_min'].max()+5, 5)
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('Distribution of Trip Duration In Minutes')
plt.hist(data = df, x = 'duration_min', bins = bins);
plt.xlim((0,200));

# %% [markdown]
# **Observation**
#
# - The distribution of Trip Duration in minutes is looks closer to normal distribution or bell-curve shape.
# - The Trip Duration is mostly centered on values which are less than 60 minutes with peak around 20 minutes.

# %% [markdown]
# **Resources:**
#
# - Udacity Classroom, Lesson 3: Univariate Exploration of Data, 8.Histograms.
#
# - Udacity classroom, Lesson 4: Bivariate Exploration of Data.
#
# - Use the documentation [Website](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html?highlight=subplot#matplotlib.pyplot.subplot), Use **matplotlib.pyplot.subplot()** function to dd a subplot to the current figure.
#
# - Use the documentation [Website](https://stackoverflow.com/questions/31726643/how-do-i-get-multiple-subplots-in-matplotlib), Get Multiple Subplots in Matplotlib.

# %%
# Seaborn Distribution of Trip Duration

# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27])
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('Distribution of Trip Duration In Minutes')
# Use seaborn.distplot() function to fexibly plot a univariate distribution of observations.
sb.distplot(df['duration_min'], bins=10)
plt.show();
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Observation**
#
# - The Trip Duration is mostly centered on values which are less than 60 minutes with peak around 20 minutes.

# %%
# Set bins
bin_edges = np.arange(0, df['duration_min'].max()+10, 10)

# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27]);
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('Distribution of Trip Duration In Minutes');
# Use seaborn.distplot() function to fexibly plot a univariate distribution of observations
sb.distplot(df['duration_min'], bins = bin_edges, kde = False, hist_kws = {'alpha' : 1});
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Plot the distribution of the Trip Duration on the vertical axis:

# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27])
# Use seaborn.distplot() function to fexibly plot a univariate distribution of observations
sb.distplot(df['duration_min'], vertical=True)

plt.title('Density of Duration Trip in minutes');
plt.xlabel('Duration Trip in minutes');
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:1649: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Resources:**
#
# - Udacity Classroom, Lesson 3: Univariate Exploration of Data, 8.Histogram.
#
# - Use the documentation [Website](https://seaborn.pydata.org/generated/seaborn.distplot.html?highlight=distplot#seaborn.distplot), Use **seaborn.distplot()** function to flexibly plot a univariate distribution of observations.
#
# - Use the documentation [Website](https://pythonbasics.org/seaborn-distplot/), Seaborn Distplot.
#
# - Use the documentation [Website](https://datascience.stackexchange.com/questions/66528/seaborn-distplot-and-kde-data-confusion), Seaborn distplot and KDE data confusion.

# %% [markdown]
# **Violin Plots**
#
# - There are a few ways of plotting the relationship between one quantitative and one qualitative variable, that demonstrate the data at different levels of abstraction. The violin plot is on the lower level of abstraction.
# - For each level of the categorical variable, a distribution of the values on the numeric variable is plotted.
# - The distribution is plotted as a kernel density estimate, something like a smoothed histogram.
# - Seaborn's violinplot() function can be used to create violin plots, or to draw a combination of boxplot and kernel density estimate.

# %%
df.duration_min.describe()
# Out:
# count    174952.000000
# mean         11.733379
# std          27.370082
# min           1.016667
# 25%           5.383333
# 50%           8.500000
# 75%          13.150000
# max        1409.133333
# Name: duration_min, dtype: float64

# %%
# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27])
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('Distribution of Trip Duration In Minutes');
# Use seaborn.violinplot() function to draw a combination of boxplot and kernel density estimate
sb.violinplot(data = df, x = 'duration_min');

# %% [markdown]
# **Observation**
#
# - The maximum value and the minimum value of trip duration in minutes are 1409.13 minutes and 1.016 minutes, respectively.

# %%
# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27])
# Use seaborn.set() function to set the aesthetic style of the plots.
sb.set(style = 'whitegrid') 
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('Distribution of Trip Duration In Minutes')
# Use seaborn.violinplot() function to draw a combination of boxplot and kernel density estimate.
sb.violinplot(data = df, x = 'duration_min');

# %% [markdown]
# **Observation**
#
# - The maximum value and the minimum value of trip duration in minutes are 1409.13 minutes and 1.016 minutes, respectively.

# %% [markdown]
# **Resources:**
#
# - Udacity Classroom, Lesson 4: Bivariate Exploration of Data, 6.Violinplot.
#
# - Use the documentation [Website](https://seaborn.pydata.org/generated/seaborn.violinplot.html?highlight=violin#seaborn.violinplot), Use **seaborn.violinplot()** function to to draw a combination of boxplot and kernel density estimate.
#
# - Use the documentation [Website](https://www.geeksforgeeks.org/violinplot-using-seaborn-in-python/), Violinplot Using Seaborn in Python.
#
# - Use the documentation [Website](https://stackabuse.com/seaborn-violin-plot-tutorial-and-examples/), Seaborn Violinplot, Tutorial and Examples.

# %% [markdown]
# #### Plotting 'member age' feature

# %%
# plot the distribution of the member age

# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27]);
# Use matplotlib.pyplot.hist() to plot a historgram.
plt.hist(data=df, x='member_age');
# Use matplotlib.pyplot.xlabel to set the label for the x-axis.
plt.xlabel('Age');
# Use matplotlib.pyplot.ylabel to set the label for the y-axis.
plt.ylabel('Frequency');
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('Frequencies in Aging');
# Use matplotlib.pyplot.show () function to display all open figures.
plt.show();

# %% [markdown]
# **Observation**
# - The most bikers are between 25 to 40 years old.

# %%
# Ploting the Distribution of the bikers' age

# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27])
# Use seaborn.distplot() function to felxibly plot a univariate distribution of observation
sb.displot(df['member_age'], kind='hist');
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('Frequency in Aging');
# Use matplotlib.pyplot.xlabel to set the label for the x-axis
plt.xlabel('Age');
# Use matplotlib.pyplot.ylabel to set the label for the y-axis.
plt.ylabel('Counts');
# Use matplotlib.pyplot.show () function to display all open figures.
plt.show();

# %% [markdown]
# **Observation**
# - The most bikers are between 25 to 40 years old.

# %%
# plot the distribution of the bikers' age

# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[8, 6])
# Set bins
bins = np.arange(0, df['member_age'].max()+5, 5)
# Use matplotlib.pyplot.hist() function to plot a histogram.
plt.hist(data=df, x='member_age', bins=bins);
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('The Distribution of Member Age');
# Use matplotlib.pyplot.xlabel to set the label for the x-axis
plt.xlabel('Age');
# Use matplotlib.pyplot.ylabel to set the label for the y-axis.
plt.ylabel('Frequency');
# Use matplotlib.pyplot.show () function to display all open figures.
plt.show();

# %% [markdown]
# **Observation**
#
# The most bikers are between 25 to 40 years old.

# %% [markdown]
# **Boxplots**
#
# - A box plot is another way of showing the relationship between a numeric variable and a categorical variable.
# - Compared to the violin plot, the box plot leans more on the summarization of the data, primarily just reporting a set of descriptive statistics for the numeric values on each categorical level.
# - A box plot can be created using seaborn's boxplot() function.
# - A boxplot, also called a box and whisker plot, is a way to show the spread and centers of a data set.
# - Measures of spread include the interquartile range and the mean of the data set.
# - Measures of center include the mean or average and median (the middle of a data set).
# - Five pieces of information (the “five number summary“) are generally included in the chart:
# - The minimum (the smallest number in the data set) is shown at the far down of the chart, at the end of the down “whisker.”
# - First quartile, Q1, is the far down of the box (or the far end of the down whisker).
# - The median is shown as a line in the center of the box.
# - Third quartile, Q3, shown at the far upper of the box (at the far upper of the upper whisker).
# - The maximum (the largest number in the data set), shown at the far upper of the box.
# - If your data set has outliers, the box and whiskers chart may not show the minimum or maximum value. Instead, the ends of the whiskers represent one and a half times the interquartile range (1.5*IQR).

# %%
# Draw a single vartical boxplot:

# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27]);
# Use matplotlib.pyplot.ylim() function to get or set the y-limits of the current axes
plt.ylim([10,65]);
# Use seaborn.boxplot() function to draw a box plot to show distributions with respect to categories
sb.boxplot(data = df, y = 'member_age');

# %%
# Draw a single Horizontal boxplot:

# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27]);
# Use matplotlib.pyplot.xlim() function to get or set the x-limits of the current axes
plt.xlim([10,65]);
# Use seaborn.boxplot() function to draw a box plot to show distributions with respect to categories
sb.boxplot(data = df, x = 'member_age');

# %%
# Draw a single vartical boxplot:

# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27])
# Use matplotlib.pyplot.ylim() function to get or set the y-limits of the current axes
plt.ylim([10,65]);
# Use seaborn.boxplot() function to draw a box plot to show distributions with respect to categories
sb.boxplot(data = df, y = 'member_age', width=.3);

# %%
# Draw a single vartical boxplot of member age"

# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27]);
# Use matplotlib.pyplot.ylim() function to get or set the y-limits of the current axes
plt.ylim([10,65]);
# Use pandas.DataFrame.boxplot() function to make a box plot from DataFrame columns.
df.boxplot(column =['member_age']);

# %% [markdown]
# **Resources:**
#
# - Udacity classroom, Lesson 4: Bivariate Exploration of Data.
#
# - Use the documentation [Website](https://seaborn.pydata.org/generated/seaborn.boxplot.html?highlight=boxplot#seaborn.boxplot), Use **seaborn.boxplot()** function to draw a box plot to show distributions with respect to categories.
#
# - Use the documentation [Website](https://pythonbasics.org/seaborn-boxplot/), Seaborn Boxplot.
#
# - Use the documentation [Website](https://www.geeksforgeeks.org/box-plot-visualization-with-pandas-and-seaborn/), Box Plot Visualization with Pandas and Seaborn.

# %%
df['member_age'].describe()
# Out:
# count    174952.000000
# mean         36.196865
# std          10.118731
# min          20.000000
# 25%          29.000000
# 50%          34.000000
# 75%          41.000000
# max         143.000000
# Name: member_age, dtype: float64

# %% [markdown]
# - It is unusual that the maximum member age is 143 years.
# - The data is not distributed evenly, so let's calculate the Interquartile Range (IQR).
# - IQR = Q3 - Q1 = 41 - 29 = 12.
# - Upper Wisker Bound = (1.5 * IQR) + Q3 = 59.

# %%
# Remove the outliers
df = df[df['member_age'] <= 60]

# %%
# plot the distribution of the bikers' age

# Set bins (A histogram displays numerical data by grouping data into "bins" of equal width.)
bins = np.arange(18, df['member_age'].max()+2, 2)

# Use matplotlib.pyplot.hist() function to plot a histogram.
plt.hist(data = df, x = 'member_age', bins = bins);

# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('The Distribution of the Member Age');
# Use matplotlib.pyplot.xlabel to set the label for the x-axis
plt.xlabel('Age');
# Use matplotlib.pyplot.ylabel to set the label for the y-axis.
plt.ylabel('Counts');
# Use matplotlib.pyplot.show () function to display all open figures.
plt.show();

# %% [markdown]
# #### Plotting 'member_birth_year' feature

# %%
df['member_birth_year'].describe()
# Out:
# count    169992.000000
# mean       1985.694597
# std           8.669889
# min        1961.000000
# 25%        1981.000000
# 50%        1987.000000
# 75%        1992.000000
# max        2001.000000
# Name: member_birth_year, dtype: float64

# %%
# Plotting distribution of age derived from member's birth year.

# Set bins (A histogram displays numerical data by grouping data into "bins" of equal width)
bins = np.arange(0, df['member_birth_year'].astype(float).max()+.50, .50)
# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[8, 5])
# Use matplotlib.pyplot.hist() function to plot a histogram.
plt.hist(data = df, x = 'member_birth_year', bins = bins)
# Use matplotlib.pyplot.axis() function to get or set properties of x-axis and y-axis.
plt.axis([1961, 2001, 0, 12000])
# Use matplotlib.pyplot.xticks() function to get or set the current tick locations and labels of the x-axis.
plt.xticks([1961, 1971, 1981, 1991, 2001], [(2001-1961), (2001-1971), (2001-1981), (2001-1991),(2021-2001)])
# Use matplotlib.pyplot.gca() function to get the current axes, creating one if necessary,
# and invert_xaxis() to reverse x-axes.
plt.gca().invert_xaxis()
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('Distribution of User Age')
# Use matplotlib.pyplot.xlabel to set the label for the x-axis
plt.xlabel('Age')
# Use matplotlib.pyplot.ylabel to set the label for the y-axis.
plt.ylabel('Number of Users')
# Use matplotlib.pyplot.show () function to display all open figures.
plt.show();

# %%
# Use seaborn.distplot() function to felxibly plot a univariate distribution of observation
sb.displot(df['member_age'], kind='hist');

# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('The Distribution of Member Age');
# Use matplotlib.pyplot.xlabel to set the label for the x-axis.
plt.xlabel('Age');
# Use matplotlib.pyplot.ylabel to set the label for the y-axis.
plt.ylabel('Count');
# Use matplotlib.pyplot.show () function to display all open figures.
plt.show();

# %% [markdown]
# **Observation**
#
# - The most bikers are between 25 to 40 years old.

# %% [markdown]
# #### Plotting 'user_type' feature

# %%
df['user_type'].value_counts()
# Out:
# Subscriber    153736
# Customer       16256
# Name: user_type, dtype: int64

# %%
df['user_type'].value_counts(normalize=True)
# Out:
# Subscriber    0.904372
# Customer      0.095628
# Name: user_type, dtype: float64

# %%
# Plot the distribution of both Customers and Subscribers

# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27])
# Use seaborn.countplot() function to show the counts of observations in each categorical bin using bars
sb.countplot(data=df, x='user_type');

# Use matplotlib.pyplot.title to set a title for the axes.
plt.title('Frequencies of Customers vs. Subscriber');
# Use matplotlib.pyplot.title to set a title for the axes.
plt.xlabel('User Type');
# Use matplotlib.pyplot.ylabel to set the label for the y-axis.
plt.ylabel('Frequencies');
# Use matplotlib.pyplot.show () function to display all open figures.
plt.show();

# %% [markdown]
# **Observation**
#
# - The value counts of "Subscriber" is 153,736 of the total "User Type", and the value counts of "Customer" is 16,256 of total "User Type".
# - The percentage of "Subscriber" is representing approximately 90% of "User Type" and the "Customer" is representing approximately 10% of "User Type.
# - In other words,the number of times a data value occurs or the frequency of "Subscriber" is greater than the frequency of "Customer" in the User Type feature, they are representing more than 140,000 times and more than 20,000 times respectively.

# %%
# plotting types of users 
plt.figure(figsize=[ 11.69, 8.27])
plt.bar(x = df.user_type.value_counts().keys(), height = df.user_type.value_counts())

# Use matplotlib.pyplot.title to set a title for the axes.
plt.title('Distribution of Customer vs. Subscriber');
# Use matplotlib.pyplot.title to set a title for the axes.
plt.xlabel('User Type');
# Use matplotlib.pyplot.ylabel to set the label for the y-axis.
plt.ylabel('No. of Users');
# Use matplotlib.pyplot.show () function to display all open figures.
plt.show();

# %% [markdown]
# **Observation**
#
# - The value counts of "Subscriber" is 153,736 of the total "User Type", and the value counts of "Customer" is 16,256 of total "User Type".
# - The percentage of "Subscriber" is representing approximately 90% of "User Type" and the "Customer" is representing approximately 10% of "User Type.
# - In other words,the number of times a data value occurs or the frequency of "Subscriber" is greater than the frequency of "Customer" in the User Type feature, they are representing more than 140,000 times and more than 20,000 times respectively.

# %%
# Plot the distribution of user type
# Use matplotlib.pyplot.pie() function to plot a pie chart
sorted_counts = df['user_type'].value_counts()
# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27]);
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('The Distribution of User Type, Subscriber vs. Customer');
# Use matplotlib.pyplot.pie() function to plot a pie chart
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90, counterclock = False, autopct='%1.1f%%');
# Use matplotlib.pyplot.axis('square') to create a square plot with equal axes
plt.axis('square');

# Use matplotlib.pyplot.legend() function to place a legend on the axes 
plt.legend(title ="User Type",loc ="upper left",bbox_to_anchor =(1, 0, 0.5, 1));  
# Use matplotlib.pyplot.show() function to display all figures. 
plt.show();

# %% [markdown]
# **Observation**
#
# - The value counts of "Subscriber" is 153,736 of the total "User Type", and the value counts of "Customer" is 16,256 of total "User Type".
# - The percentage of "Subscriber" is representing approximately 90% of "User Type" and the "Customer" is representing approximately 10% of "User Type.
# - In other words,the number of times a data value occurs or the frequency of "Subscriber" is greater than the frequency of "Customer" in the User Type feature, they are representing more than 140,000 times and more than 20,000 times respectively.

# %%
# Plot the distribution of user type
# Use matplotlib.pyplot.pie() function to plot a pie chart (Donut chart)
sorted_counts = df['user_type'].value_counts()
# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27])
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('The Distribution of Subscriber vs. Customer');
# Use matplotlib.pyplot.pie() function to plot a pie chart, with this parameters to create the donut plot.
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90, counterclock = False, wedgeprops = {'width' : 0.4});
# Use matplotlib.pyplot.axis('square') to create a square plot with equal axes
plt.axis('square');
# Use matplotlib.pyplot.legend() function to place a legend on the axes 
plt.legend(title ="User Type",loc ="upper left",bbox_to_anchor =(1, 0, 0.5, 1));  
# Use matplotlib.pyplot.show() function to display all figures. 
plt.show();

# %% [markdown]
# **Observation**
#
# - The value counts of "Subscriber" is 153,736 of the total "User Type", and the value counts of "Customer" is 16,256 of total "User Type".
# - The percentage of "Subscriber" is representing approximately 90% of "User Type" and the "Customer" is representing approximately 10% of "User Type.
# - In other words,the number of times a data value occurs or the frequency of "Subscriber" is greater than the frequency of "Customer" in the User Type feature, they are representing more than 140,000 times and more than 20,000 times respectively.

# %% [markdown]
# #### Plotting 'member_gender' feature

# %%
df['member_gender'].value_counts()
# Out:
# Male      126311
# Female     40098
# Other       3583
# Name: member_gender, dtype: int64

# %%
df.member_gender.value_counts(normalize=True)
# Out:
# Male      0.743041
# Female    0.235882
# Other     0.021077
# Name: member_gender, dtype: float64

# %%
# plotting the distribution of Bikers' gender

# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27])
# Use matplotlib.pyplot.bar() function to make a bar plot.
plt.bar(x = df.member_gender.value_counts().keys(), height = df.member_gender.value_counts() )
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('Distribution of Gender')
# Use matplotlib.pyplot.xlabel to set the label for the x-axis
plt.xlabel('Gender')
# Use matplotlib.pyplot.ylabel to set the label for the y-axis.
plt.ylabel('Number of Users')
# Use matplotlib.pyplot.show () function to display all open figures.
plt.show();

# %% [markdown]
# **Observation**
#
# - The male bikers are about three times of female bikers.
# - The value counts of "Male", "Female", and "Other" are 126311, 40098, and 3583 respectively.
# - However, the percentage of "Male" is approximately 74%, "Female" is approximately 24%, and "Other" is approximately 2% off the "Gender" feature.
# - In other words,the number of times a data value occurs or the frequency of "Male" is greater than the frequency of "Female" and "Other" in the "Gender" feature.

# %%
# Ploting the distribution of bikers' gender

# Use matplotlib.pyplot.pie() function to plot a pie chart
sorted_counts = df['member_gender'].value_counts()
# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27]);
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('The Distribution of Gender');
# Use matplotlib.pyplot.pie() function to plot a pie chart
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90, counterclock = False, autopct='%1.1f%%');
# Use matplotlib.pyplot.axis('square') to create a square plot with equal axes
plt.axis('square');
# Use matplotlib.pyplot.legend() function to place a legend on the axes 
plt.legend(title ="Gender",loc ="upper left",bbox_to_anchor =(1, 0, 0.5, 1));  
# Use matplotlib.pyplot.show() function to display all figures. 
plt.show();

# %% [markdown]
# **Observation**
#
# - The male bikers are about three times of female bikers.
# - The value counts of "Male", "Female", and "Other" are 126311, 40098, and 3583 respectively.
# - However, the percentage of "Male" is approximately 74%, "Female" is approximately 24%, and "Other" is approximately 2% off the "Gender" feature.
# - In other words,the number of times a data value occurs or the frequency of "Male" is greater than the frequency of "Female" and "Other" in the "Gender" feature.

# %% [markdown]
# #### Plotting 'bike_share_for_all_trip' feature

# %%
df['bike_share_for_all_trip'].value_counts()
# Out:
# No     153338
# Yes     16654
# Name: bike_share_for_all_trip, dtype: int64

# %%
df['bike_share_for_all_trip'].value_counts(normalize=True)
# Out:
# No     0.902031
# Yes    0.097969
# Name: bike_share_for_all_trip, dtype: float64

# %%
# Plot the distribution of Bike Share for all Trip

# Use seaborn.countplot() function to show the counts of observations in each categorical bin using bars
sb.countplot(data=df, x='bike_share_for_all_trip');

# Use matplotlib.pyplot.title to set a title for the axes.
plt.title('Counts of Bike Share for all Trips');
# Use matplotlib.pyplot.xlabel to set the label for the x-axis.
plt.xlabel('Bike Share of all Trips');
# Use matplotlib.pyplot.ylabel to set the label for the y-axis.
plt.ylabel('Count');
# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27]);
# Use matplotlib.pyplot.show () function to display all open figures.
plt.show();

# %% [markdown]
# **Observation**
#
# - The value counts of "No", "Yes" off the "Bike Share of all Trip  are 153,338, and 16654 respectively.
# - However, the percentage of "No" is approximately 90%, and "Yes" is approximately 10% off the "Bike Share of all trip" feature.

# %%
# Plotting the distribution of Bike Share for all Trips

# Use matplotlib.pyplot.pie() function to plot a pie chart
sorted_counts = df['bike_share_for_all_trip'].value_counts()
# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27]);
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('The Distribution of Bike Share For All Trips');
# Use matplotlib.pyplot.pie() function to plot a pie chart
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90, counterclock = False, autopct='%1.1f%%');
# Use matplotlib.pyplot.axis('square') to create a square plot with equal axes
plt.axis('square');
# Use matplotlib.pyplot.legend() function to place a legend on the axes 
plt.legend(title ="Bike Share",loc ="upper left",bbox_to_anchor =(1, 0, 0.5, 1));  
# Use matplotlib.pyplot.show() function to display all figures. 
plt.show();

# %% [markdown]
# **Observation**
#
# - The value counts of "No", "Yes" off the "Bike Share of all Trip  are 153,338, and 16654 respectively.
# - However, the percentage of "No" is approximately 90%, and "Yes" is approximately 10% off the "Bike Share of all trip" feature.

# %% [markdown]
# #### Conclusion

# %% [markdown]
# **Discuss the distribution(s) of your variable(s) of interest. Were there any unusual points? Did you need to perform any transformations?**
#
# - The mean or average of Trip duration in minutes is 11.73 minutes, maximum value is 1409.13 minutes, and the minimum value is 1.016 minutes.
#
# - The maximum of member ages are 143 years old, it is unusual, so I need to remove the outliers, the member ages greater than 60 years old.
#
# - The plotting of distribution of age reveals that it more concentrated between 25 to 40 years old.
#
# - From the start time hour, the time 8:00 AM and 5:00 PM are the two peak hours which have most bikers.
#
# - It seems to be that the distribution of both start stations and end stations are same.
#
# - The Biker subscribers and customers are representing approximately 90% and 10% percentage, respectively. However, the number of subscriber is 153736 and the number of customer is 16256.
#
# - The male bikers are about three times of female bikers. However, the number of male is 126,311 with percentage of  74%, the number of female is 40,098 with percentage of 24%, and the number of other is 3583 with percentage of 2%.
#
# **Of the features you investigated, were there any unusual distributions? Did you perform any operations on the data to tidy, adjust, or change the form of the data? If so, why did you do this?**
#
# - When investigating the Birth year variables, Birth year is converted by substracting the year from current year 2021 in order to give the distibution for age and better perception.
#
# - Furthermore, start station and end station is plotted in a larger plot so that it gives a better insight regarding traffic of bikes at certain stations.

# %% [markdown]
# <h3><center> Bivariate Exploration</center></h3>

# %% [markdown]
# **In the Book "An Introduction to Statistical Learning, with Application in R", By: Gareth James, Danila Witten, Trevor Hastie, Robert Tibshirani", Chapter 3: Linear Regression, and Chapter 4: Classification**
#
# - `Simple Linear Regression` lives up to its name: it is a very straigtforward approach for predicting a quantitative response Y on the basis of a single predictor variable X. It assumes that there is approximately a linear relationship between X and Y.
#
# - However, in statistics, simple linear regression is a linear regression model with a single explanatory variable. Make a comparison of only two quantitative variables. The response variable, y-axis, dependent variable, or target is what you want to predict,while the explanatory variavle, x-axis, independent variable, or predictor is the variable I use to predict the response. A common way to visualize the relationship between two variables in linear regression is using a scatterplot.
#
#
# - Simple linear regression is a useful approach for predicting a response on the basis of a single predictor variable. However, in practice we often have more than one predictor.In `multiple linear regression`, I will use both the quantitative and categorical x-variables to predict a quantitative response. The way that I add categorical variables into the multiple linear regression models is by using the dummy variables.
# - The most common way dummy variables are added is through 1,0 encoding. When I add these dummy variables to the multiple linear regression models, I always drop one of the columns. The column I dropped is called the baseline. Furthermore, the coefficents I obtain from the output of the multiple linear regression models are then an indication of how the encoded levels compare to the baseline level (the dropped level).
#
#
# - And finally, the `logistic regression` is used to predict categorical variable. However, the linear regression model assumes that the response variable Y is quantitative. But in many situations, the response variable is instead qualitative. Often qualitative variables are referred to as categorical. There are many possible classification techniques, or classifiers, that one might use to predict a qualitative response, which is the `logistic regression`.

# %% [markdown]
# **Overview**
#
# - I am trying to figure out the correlation between the duration trip and other features such as: age, start station, end station, user type, and gende in the data.
#
# **Negative Correlation**
#
# - When the scatter plot shows a bunch of dots, where low x-values correspond to high y-values, and high x-values correspond to low y-values. It's fairly obvious to me that I could draw a straight line, starting from around the left-most dot and angling downwards as I move to the right, amongst the plotted data points, and the line would look like a good match to the points. Such a line would have a negative slope, and the plotted data points would all lie on or very close to that drawn line. So there does appear to be a strong correlation here and, because a good-fit line drawn amongst these points would have a negative slope, that correlation is negative.
#
# - In other words, the regression line in a scatter plot showing a negative correlation between the two variables.
#
# **Positive Correlation**
# - When the  Plot shows a bunch of dots, where low x-values correspond to low y-values, and high x-values correspond to high y-values. It's fairly obvious to me that I could draw a straight line, starting near the left-most dot and angline upwards as I move to the right, amongst the plotted data points, and the line would look like a good match to the points. Such a line would have a positive slope, and the plotted data points would all lie on or very close to that drawn lline. So there does appear to be a strong correlation here and, because the good-fit line drawn amongst these points would have a positive slope, that correlation is positive.
#
# - In other words, the regression line in a scatter plot showing a positive correlation between the two variables.
#
# **No Correlation**
#
# - When the data points are just all over the place, there doesn't appear to be any trend to these data points. I can't conceive of any straight line I could possibly justify drawing across this plot. Maybe additional data points could clear things up but, as things stand, I see no trends at all. With what they've given me, there is no apparent correlation between inputs and outputs.
#
# - On the other hand, when the data points line up very nicely! I can easily draw a horizontal line amongst these dots, and the line would clearly be a good fit to the data. However, the fact that the line would be horizontal means that the input values (that is, the x-values) are irrelevant to the output values (that is, the y-values). I can pick any input value I like, and the output is always going to be right around the same value.
#
# - So there is a definite trend to the data, and there is an excellent good-fit line for it, but that line only says that the input values are irrelevant. If the inputs are irrelevant, then there can't possibly be a correlation between inputs and outputs. That is, the inputs can't possibly have any relationship with the outputs, because the inputs are utterly immaterial to the outputs.

# %%
# Use matplotlib.pyplot.scatter() function to apply a scatter plot of y vs. x with varying marker size and /or color
plt.scatter(data=df, x='member_age', y='duration_min');
# Use matplotlib.pyplot.title to set a title for the axes.
plt.title('Scatter Plot of Age vs. Trip Duration');
# Use matplotlib.pyplot.xlabel to set the label for the x-axis.
plt.xlabel('Age');
# Use matplotlib.pyplot.ylabel to set the label for the y-axis.
plt.ylabel('Duration of Minutes');
# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27]);
# Use matplotlib.pyplot.show () function to display all open figures.
plt.show();

# %% [markdown]
# **Observation**
#
# - The data points are just all over the place, there doesn't appear to be any trend to these data points.
# - I can't conceive of any straight line I could possibly justify drawing across this plot.
# - Maybe additional data points could clear things up but, as things stand, I see no trends at all.
# - Overall, there is no apparent correlation between the two variables.

# %%
# Use matplotlib.pyplot.scatter() function to apply a scatter plot of y vs. x with varying marker size and /or color
plt.scatter(data=df, x='member_birth_year', y='duration_min');
# Use matplotlib.pyplot.title to set a title for the axes.
plt.title('Plotting Birth Year vs. Trip Duration');
# Use matplotlib.pyplot.xlabel to set the label for the x-axis.
plt.xlabel('Birth Year')
# Use matplotlib.pyplot.ylabel to set the label for the y-axis.
plt.ylabel('Duration of Minutes');
# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27]);
# Use matplotlib.pyplot.show () function to display all open figures.
plt.show();

# %% [markdown]
# **Observation**
#
# - The data points are just all over the place, there doesn't appear to be any trend to these data points.
# - I can't conceive of any straight line I could possibly justify drawing across this plot.
# - Maybe additional data points could clear things up but, as things stand, I see no trends at all.
# - Overall, there is no apparent correlation between the two variables.

# %% [markdown]
# **Resources:**
#
# - Udacity classroom, Lesson 4: Bivariate Exploration of Data, 2.Scatterplot and Correlation.
#
# - Use the documentation [Website](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.scatter.html?highlight=scatter#matplotlib.pyplot.scatter), Use **matplotlib.pyplot.scatter()** function to apply a scatter plot of y vs. x with varying marker size and /or color.
#
# - Use the documentation [Website](https://www.geeksforgeeks.org/matplotlib-pyplot-scatter-in-python/), Matplotlib.pyplot.scatter() in Python.

# %%
# Use seaborn.regplot() function to plot data and a linear regression model fit
sb.regplot(data=df, x='member_age', y='duration_min');
# Use matplotlib.pyplot.title to set a title for the axes.
plt.title('Plot Age vs. Trip Duration and a Linear Regression Model Fit')
# Use matplotlib.pyplot.xlabel to set the label for the x-axis.
plt.xlabel('Age');
# Use matplotlib.pyplot.ylabel to set the label for the y-axis.
plt.ylabel('Duration of Minutes');
# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27]);
# Use matplotlib.pyplot.show () function to display all open figures.
plt.show();

# %% [markdown]
# **Observation**
#
# - The data points are just all over the place, there doesn't appear to be any trend to these data points.
# - I can't conceive of any straight line I could possibly justify drawing across this plot.
# - Maybe additional data points could clear things up but, as things stand, I see no trends at all.
# - Overall, there is no apparent correlation between the two variables.

# %%
# Use seaborn.regplot() function to plot data and a linear regression model fit
sb.regplot(data=df, x='member_birth_year', y='duration_min');
# Use matplotlib.pyplot.title to set a title for the axes.
plt.title('Plot Age vs. Trip Duration and a Linear Regression Model Fit')
# Use matplotlib.pyplot.xlabel to set the label for the x-axis.
plt.xlabel('Birth Year')
# Use matplotlib.pyplot.ylabel to set the label for the y-axis.
plt.ylabel('Duration of Minutes');
# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27]);
# Use matplotlib.pyplot.show () function to display all open figures.
plt.show();

# %% [markdown]
# **Observation**
#
# - The data points are just all over the place, there doesn't appear to be any trend to these data points.
# - I can't conceive of any straight line I could possibly justify drawing across this plot.
# - Maybe additional data points could clear things up but, as things stand, I see no trends at all.
# - Overall, there is no apparent correlation between the two variables.

# %% [markdown]
# **Resources:**
#
# - Udacity classroom, Lesson 4: Bivariate Exploration of Data, 2.Scatterplots and Correlation.
#
# - Use the documentation [Website](https://seaborn.pydata.org/generated/seaborn.regplot.html), Use **seaborn.regplot()** method to Plot data and a linear regression model fit.
#
# - Use the documentation [Website](https://www.geeksforgeeks.org/python-seaborn-regplot-method/), Python – seaborn.regplot() method.

# %%
# Resize figure to accommodate two plots
plt.figure(figsize = [20, 5])

# PLOT ON LEFT - SIMPLE SCATTER
plt.subplot(1, 2, 1)
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('The Distribution of Member Birth Year During Duration Trip');
sb.regplot(data = df, x = 'member_birth_year', y = 'duration_min', truncate=False);

# PLOT ON RIGHT - SCATTER PLOT WITH JITTER
plt.subplot(1, 2, 2)
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('The Distribution of Member Birth Year During Duration Trip');

# In the sb.regplot() function below, the `truncate` argument accepts a boolean.
# If truncate=True, the regression line is bounded by the data limits. 
# Else if truncate=False, it extends to the x axis limits.
# The x_jitter will make each x value will be adjusted randomly by +/-0.3
sb.regplot(data = df, x = 'member_birth_year', y = 'duration_min', truncate=False, x_jitter=0.3);

# %% [markdown]
# **Observation**
#
# - The data points are just all over the place, there doesn't appear to be any trend to these data points.
# - I can't conceive of any straight line I could possibly justify drawing across this plot.
# - Maybe additional data points could clear things up but, as things stand, I see no trends at all.
# - Overall, there is no apparent correlation between the two variables.

# %%
# Use matplotlib.pyplot.scatter() function to apply a scatter plot of y vs. x with varying marker size and /or color
plt.scatter(data=df, x='start_station_id', y='duration_min');
# Use matplotlib.pyplot.title to set a title for the axes.
plt.title('Plotting Start Station vs. Trip Duration');
# Use matplotlib.pyplot.xlabel to set the label for the x-axis.
plt.xlabel('Start Station')
# Use matplotlib.pyplot.ylabel to set the label for the y-axis.
plt.ylabel('Duration of Minutes');
# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27]);
# Use matplotlib.pyplot.show () function to display all open figures.
plt.show();

# %% [markdown]
# **Observation**
#
# - The data points are just all over the place, there doesn't appear to be any trend to these data points.
# - I can't conceive of any straight line I could possibly justify drawing across this plot.
# - The data points line up, and I can easily draw a horizontal line amongst these dots. However, the fact that the line would be horizontal means that the x-values are irrelevant to the y-values.
# - Overall, there is no apparent correlation between the two variables.

# %%
# Use matplotlib.pyplot.scatter() function to apply a scatter plot of y vs. x with varying marker size and /or color
plt.scatter(data=df, x='end_station_id', y='duration_min');
# Use matplotlib.pyplot.title to set a title for the axes.
plt.title('Plotting End Station vs. Trip Duration');
# Use matplotlib.pyplot.xlabel to set the label for the x-axis.
plt.xlabel('End Station')
# Use matplotlib.pyplot.ylabel to set the label for the y-axis.
plt.ylabel('Duration of Minutes');
# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27]);
# Use matplotlib.pyplot.show () function to display all open figures.
plt.show();

# %% [markdown]
# **Observation**
#
# - The data points are just all over the place, there doesn't appear to be any trend to these data points.
# - I can't conceive of any straight line I could possibly justify drawing across this plot.
# - The data points line up, and I can easily draw a horizontal line amongst these dots. However, the fact that the line would be horizontal means that the x-values are irrelevant to the y-values.
# - Overall, there is no apparent correlation between the two variables.

# %%
# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize = [18, 6])

# PLOT ON LEFT
# Use matplotlib.pyplot.subplot() function to add a subplot to the current figure.
plt.subplot(1, 2, 1)
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('The Distribution of Start Time Hour vs. Duration Trip In Minutes');

# Use seaborn.regplot() function to plot data and a linear regression model fit
sb.regplot(data = df, x = 'start_time_hour', y = 'duration_min', x_jitter=0.04, scatter_kws={'alpha':1/10}, fit_reg=False)
# Use matplotlib.pyplot.xlabel to set the label for the x-axis.
plt.xlabel('Hour')
# Use matplotlib.pyplot.ylabel to set the label for the y-axis.
plt.ylabel('Day of Week');

# PLOT ON RIGHT
# Use matplotlib.pyplot.subplot() function to add a subplot to the current figure.
plt.subplot(1, 2, 2)
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('The Distribution of Start Time Hour vs. Duration Trip In Minutes');
# Use matplotlib.pyplot.hist2d() function to make a two dimensional histogram
plt.hist2d(data = df, x = 'start_time_hour', y = 'duration_min')
# Use matplotlib.pyplot.colorbar () function to add a colorbar to a Plot.
plt.colorbar()
# Use matplotlib.pyplot.xlabel to set the label for the x-axis.
plt.xlabel('Hour')
# Use matplotlib.pyplot.ylabel to set the label for the y-axis.
plt.ylabel('Day of Week');

# %% [markdown]
# **Observation**
#
# - The data points are just all over the place, there doesn't appear to be any trend to these data points.
# - I can't conceive of any straight line I could possibly justify drawing across this plot.
# - Maybe additional data points could clear things up but, as things stand, I see no trends at all.
# - Overall, there is no apparent correlation between the two variables.

# %% [markdown]
# **Heat Maps**
#
# A heat map is a 2-d version of the histogram that can be used as an alternative to a scatterplot. Like a scatterplot, the values of the two numeric variables to be plotted are placed on the plot axes. Similar to a histogram, the plotting area is divided into a grid and the number of points in each grid rectangle is added up. Since there won't be room for bar heights, counts are indicated instead by grid cell color. A heat map can be implemented with Matplotlib's hist2d() function.
#
# **Heat maps are useful in the following cases:**
#
# - To represent a plot for discrete vs. another discrete variable
# - As an alternative to transparency when the data points are enormous

# %%
# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27]);
# Use matplotlib.pyplot.hist2d() function to make a two dimentional plot
plt.hist2d(data= df, x='member_age', y= 'duration_min');
# Use matplotlib.pyplot.colorbar () function to add a colorbar to a Plot.
plt.colorbar()
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('The Distribution of Member Age During The Duration Trip In Minutes');
# Use matplotlib.pyplot.xlabel to set the label for the x-axis.
plt.xlabel('Age')
# Use matplotlib.pyplot.ylabel to set the label for the y-axis.
plt.ylabel('Duration of Minutes');

# %%
plt.figure(figsize=[ 11.69, 8.27]);
# Use matplotlib.pyplot.hist2d() function to make a two dimentional plot
plt.hist2d(data= df, x='member_birth_year', y= 'duration_min', cmin=0.5, cmap='viridis_r');
plt.colorbar()
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('The Distribution of Member Birth Year During The Duration Trip In Minutes');
plt.xlabel('Birth Year')
plt.ylabel('Duration of Minutes');

# %%
df[['member_birth_year', 'duration_min']].describe()
# Out:
#        member_birth_year   duration_min
# count      169992.000000  169992.000000
# mean         1985.694597      11.717717
# std             8.669889      27.676933
# min          1961.000000       1.016667
# 25%          1981.000000       5.383333
# 50%          1987.000000       8.483333
# 75%          1992.000000      13.100000
# max          2001.000000    1409.133333

# %%
# Use pandas.DataFrame.groupby() function to group dataframe using a mapper or by a Series of columns.
ct_counts = df.groupby(['user_type', 'member_gender']).size()
# Use pandas.DataFrame.reset_index() to reset the index or a level of it
ct_counts = ct_counts.reset_index(name='count')
# Use pandas.DataFrame.pivot() to rearrange dataframe organized by given index /column values
ct_counts = ct_counts.pivot(index='user_type', columns='member_gender', values='count')
ct_counts
# Out:
# member_gender  Female    Male  Other
# user_type
# Customer         4535   11292    429
# Subscriber      35563  115019   3154

# %%
# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27]);
# Use seaborn.heatmap() function to Plot rectangular data as a color-encoded matrix.
sb.heatmap(ct_counts, annot=True, fmt='d');
plt.title('Plotting Heatmap of Member Gender vs. User Type');

# %% [markdown]
# **Resources:**
#
# - Udacity classroom, Lesson 4: Bivariate Exploration of Data, 4.Heatmap.
#
# - Use the documentation [Website](https://seaborn.pydata.org/generated/seaborn.heatmap.html?highlight=heatmap#seaborn.heatmap), Use **seaborn.heatmap()** function to Plot rectangular data as a color-encoded matrix.
#
# - Use the documentation [Website](https://towardsdatascience.com/heatmap-basics-with-pythons-seaborn-fb92ea280a6c), Heatmap basics with Pythons seaborn.

# %% [markdown]
# **Correlation Matrix Plots**
#
# - Heatmaps visualize the data in a 2-dimensional format in the form of colored maps. The color maps use hue, saturation, or luminance to achieve color variation to display various details. This color variation gives visual cues to the readers about the magnitude of numeric values. HeatMaps is about replacing numbers with colors because the human brain understands visuals better than numbers, text, or any written data. Human beings are visual learners; therefore, visualizing the data in any form makes more sense.
#
# - Heatmaps can describe the density or intensity of variables, visualize patterns, variance, and even anomalies. Heatmaps show relationships between variables. These variables are plotted on both axes. We look for patterns in the cell by noticing the color change. It only accepts numeric data and plots it on the grid, displaying different data values by varying color intensity.
#
# - A correlation matrix denotes the correlation coefficients between variables at the same time. A heat map grid can represent these coefficients to build a visual representation of the variables’ dependence. This visualization makes it easy to spot the strong dependencies. A positive correlation indicates a strong dependency, while a negative correlation indicates a strong inverse dependency; a correlation coefficient closer to zero indicates weak dependence.
#
# - The heatmap transforms the correlation matrix into color codings. The correlation matrix shows how the variables are correlated to each other on a scale of -1 to 1. 1 being positively correlated and -1 being inversely correlated. As only numerical features can show the correlation, the heatmap cannot visualize categorical features.

# %%
# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27]);
plt.title('Plotting Heatmap of Correlation Matrix');
# Use seaborn.heatmap() function to plot rectangular data as a color-encoded matrix.
# Use Pandas dataframe.corr() is used to find the pairwise correlation of all columns in the dataframe.
# Any na values are automatically excluded. For any non-numeric data type columns in the dataframe it is ignored.
sb.heatmap(df.corr(), annot = True, fmt = '.3f', cmap = 'vlag_r', center = 0);

# %% [markdown]
# **Observation**
#
# - The blue color with a positive number means positive correlation between the two variables, however, the red color with minus number means negative correlation between the two variables. The stronger the color, the larger the correlation magnitude.
#
# - Start Station Latitute has the highest positive correlation with End Station Latitude.
# - Start Station Longitude has the highest positive correlation with End Station Longitude.
# - Duration Minutes has the highest positive correlation with Duration Seconds.
#
# - Start Station Latitute has the highest negative correlation with End Station Longitude, followed by Start Station Longitude.
# - Start Station Longitude has the highest negative correlation with End Station Latitude, followed by Start Station Latitude.

# %% [markdown]
# **Bar Plots**
#
# - A barplot is basically used to aggregate the categorical data according to some methods and by default it’s the mean. It can also be understood as a visualization of the group by action. To use this plot we choose a categorical column for the x-axis and a numerical column for the y-axis, and we see that it creates a plot taking a mean per categorical column.
# - Use seaborn.barplot() method to Show point estimates and confidence intervals as rectangular bars.

# %%
# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27]);
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('The Distribution of Days of the Week During The Duration Trip');
# Use seaborn.barplot() method to Show point estimates and confidence intervals as rectangular bars.
sb.barplot(data=df, x= 'start_time_dayofweek', y='duration_min');

# %% [markdown]
# **Observation**
#
# - The weekends (Saturdays and Sundays) are the highest duration trip over the days of the week.

# %%
# Show value counts for two categorical variables:
# Use seaborn.countplot()** function to show the counts of observations in each categorical bin using bars.
plt.figure(figsize=[ 11.69, 8.27]);
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('The Distribution of Start Time Hour During The Days of the Week');
sb.countplot(x="start_time_hour", hue="start_time_dayofweek", data=df);

# %% [markdown]
# **Observation**
#
# - Thursday has the highest biker counts across the seven days.
# - An 8:00 AM and 5:00 PM have the highest across the seven days.
# - At 5:00 PM, on every Tuesday has the highest biker counts across the seven days, and twenty-four hours.

# %%
plt.figure(figsize=[ 11.69, 8.27]);
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('The Distribution of Start Time Hour During The Days of the Week');
sb.countplot(data = df, x = 'start_time_hour', hue = 'start_time_dayofweek');

# %% [markdown]
# **Observation**
#
# - Thursday has the highest biker counts across the seven days.
# - An 8:00 AM and 5:00 PM have the highest across the seven days.
# - At 5:00 PM, on every Tuesday has the highest biker counts across the seven days, and twenty-four hours.

# %%
plt.figure(figsize=[ 11.69, 8.27]);
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('The Distribution of Start Time Hour vs.Member Gender');
sb.countplot(data = df, x = 'start_time_hour', hue = 'member_gender');

# %% [markdown]
# **Observation**
#
# - An 8:00 AM and 5:00 PM have the highest across the seven days, and twenty-four hours.
# - The male has the highest biker counts over the female, especially during the 8:00 AM and 5:00 PM.

# %%
plt.figure(figsize=[ 11.69, 8.27]);
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('The Distribution of User Type vs. Start Time Hour');
sb.countplot(data = df, x = 'start_time_hour', hue = 'user_type');

# %% [markdown]
# **Observation**
#
# - An 8:00 AM and 5:00 PM have the highest across the seven days, and twenty-four hours.
# - The subscriber has the highest biker counts over the customer across the seven days, and twenty-four hours.

# %%
plt.figure(figsize=[ 11.69, 8.27]);
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('The Distribution of Start Time Day of the Week vs. Member Gender');
sb.countplot(data = df, x = 'start_time_dayofweek', hue = 'member_gender');

# %% [markdown]
# **Observation**
#
# - Thursday has the highest biker counts across the seven days.
# - The male has the highest biker counts over the female across the seven days,especially on Tuesday.

# %%
plt.figure(figsize=[ 11.69, 8.27]);
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('The Distribution of User Type vs. Start Time Day of the Week');
sb.countplot(data = df, x = 'start_time_dayofweek', hue = 'user_type');

# %% [markdown]
# **Observation**
#
# - Thursday has the highest biker counts across the seven days.
# - The subscriber has the highest biker counts over the customer, especially on Tuesday, compare to other days.

# %%
plt.figure(figsize=[ 11.69, 8.27]);
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('The Distribution of Member Gender vs. User Type');
sb.countplot(data = df, x = 'member_gender', hue = 'user_type');

# %% [markdown]
# **Observation**
#
# - Most 'Customer' and 'Subscribers' bikers are male.
# - Most male are subcriber rather than customer.

# %% [markdown]
# **Violin Plots**
#
# There are a few ways of plotting the relationship between one quantitative and one qualitative variable, that demonstrate the data at different levels of abstraction. The violin plot is on the lower level of abstraction. For each level of the categorical variable, a distribution of the values on the numeric variable is plotted. The distribution is plotted as a kernel density estimate, something like a smoothed histogram. There is an extra section at the end of the previous lesson that provides more insight into kernel density estimates.

# %%
plt.figure(figsize=[ 11.69, 8.27])
plt.title('Ploting Gender vs. Duration Trip')
# Use seaborn.violinplot() function to draw a combination of boxplot and kernel density estimate.
sb.violinplot(data=df, x='member_gender', y='duration_min');

# %% [markdown]
# **Observation**
#
# The previous figure reveal the trip duration (in minutes) in all member gender (female, male, and other)

# %%
plt.figure(figsize=[ 11.69, 8.27]);
plt.title('Ploting User Type vs. Duration Trip');
# Use seaborn.violinplot() function to draw a combination of boxplot and kernel density estimate.
sb.violinplot(data=df, x='user_type', y='duration_min');

# %% [markdown]
# **Observation**
#
# The previous figure reveal the trip duration (in minutes) in all user type (customer, and Subscriber)

# %%
df['start_time_dayofweek']
# Out:
# 0         Thu
# 2         Thu
# 3         Thu
# 4         Thu
# 6         Thu
#          ...
# 183407    Fri
# 183408    Fri
# 183409    Fri
# 183410    Fri
# 183411    Fri
# Name: start_time_dayofweek, Length: 169992, dtype: category
# Categories (7, object): ['Mon' < 'Tue' < 'Wed' < 'Thu' < 'Fri' < 'Sat' < 'Sun']

# %%
# Duration during the days of week
day_of_week = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']

# Refer - https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.api.types.CategoricalDtype.html
weekday = pd.api.types.CategoricalDtype(ordered=True, categories=day_of_week)

# Use pandas.astype() to convert the "start_time_dayofweek" column from a plain object type into an ordered categorical type 
df['start_time_dayofweek'] = df['start_time_dayofweek'].astype(weekday);

plt.figure(figsize=[ 11.69, 8.27]);
plt.ylim([0,200]);

sb.violinplot(data=df, x='start_time_dayofweek', y='duration_min');

# %% [markdown]
# **Observation**
#
# - The previous figure reveal the trip duration (in minutes) in day of the week.
# - The duration trip (in minutes) at Monday through Friday, and Sunday are slightly less than those who ride on Saturdays.

# %%
base_color = sb.color_palette()[0]

plt.figure(figsize=[ 11.69, 8.27]);
plt.ylim([0,200]);

# The "inner" argument represents the datapoints in the violin interior. 
# It can take any value from {“box”, “quartile”, “point”, “stick”, None}
# If "box", it draws a miniature boxplot. 
sb.violinplot(data=df, x='start_time_dayofweek', y='duration_min', color=base_color, innner=None);

# %% [markdown]
# **Observation**
#
# - The previous figure reveal the trip duration (in minutes) in day of the week.
# - The duration trip (in minutes) at Monday through Friday, and Sunday are slightly less than those who ride on Saturdays.

# %%
df['user_type'].value_counts(), df['user_type'].value_counts(normalize=True)
# Out:
# (Subscriber    153736
#  Customer       16256
#  Name: user_type, dtype: int64,
#  Subscriber    0.904372
#  Customer      0.095628
#  Name: user_type, dtype: float64)

# %%
# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize = [20, 10])
# Use seaborn.boxplot() function to draw a box plot to show distributions with respect to categories.
sb.boxplot(data=df, x='user_type', y='duration_min');
# Use matplotlib.pyplot.xlim() function to get or set the x limits of the current axes.
plt.ylim([0, 300])
# Use matplotlib.pyplot.title() to set a title for the axes.
plt.title('Trip Duration in Minutes and User Type')
# Use matplotlib.pyplot.xlabel to set the label for the x-axis.
plt.xlabel('User Type')
# Use matplotlib.pyplot.ylabel to set the label for the y-axis.
plt.ylabel('Duration Trip in Minute')
# Use matplotlib.show() function to display all open figures.
plt.show();

# %% [markdown]
# **Observation**
#
# - The higher percentage of customer rides longer trips than subscriber although number of subscriber riders are higher than customer.
#
# - However, the value counts of "Subscriber" is 153,736 of the total "User Type", and the value counts of "Customer" is 16,256 of total "User Type". Furthermore, the percentage of "Subscriber" is representing approximately 90% of "User Type" and the "Customer" is representing approximately 10% of "User Type.

# %% [markdown]
# **Faceting**
#
# - The Faceted plot is a multiple copies of the same type of plot visualized on different subsets of the data.
#
# - One general visualization technique that will be useful for you to know about to handle plots of two or more variables is faceting. In faceting, the data is divided into disjoint subsets, most often by different levels of a categorical variable. For each of these subsets of the data, the same plot type is rendered on other variables.
#
# - Faceting is a way of comparing distributions or relationships across levels of additional variables, especially when there are three or more variables of interest overall. While faceting is most useful in multivariate visualization, it is still valuable to introduce the technique here in our discussion of bivariate plots.
#
# - FacetGrid class helps in visualizing distribution of one variable as well as the relationship between multiple variables separately within subsets of your dataset using multiple panels.
#
# - A FacetGrid can be drawn with up to three dimensions ? row, col, and hue. The first two have obvious correspondence with the resulting array of axes; think of the hue variable as a third dimension along a depth axis, where different levels are plotted with different colors.
#
# - FacetGrid object takes a dataframe as input and the names of the variables that will form the row, column, or hue dimensions of the grid. The variables should be categorical and the data at each level of the variable will be used for a facet along that axis.

# %%
# Trip Duration during the days of week
# Convert the "start_time_dayofweek" column from a plain object type into an ordered categorical type
day_of_week = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']

# Refer - https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.api.types.CategoricalDtype.html
weekday = pd.api.types.CategoricalDtype(ordered=True, categories=day_of_week)

# Use pandas.astype() to convert the "start_time_dayofweek" column from a plain object type into an ordered categorical type 
df['start_time_dayofweek'] = df['start_time_dayofweek'].astype(weekday);

# Plot the Seaborn's FacetGrid
g = sb.FacetGrid(data = df, col = 'start_time_dayofweek')
g.map(plt.hist, "duration_min");
g.add_legend();

# %% [markdown]
# **Observation**
#
# - Thursday has the highest trip duration over the days of the week.

# %%
df['duration_min'].describe()
# Out:
# count    169992.000000
# mean         11.717717
# std          27.676933
# min           1.016667
# 25%           5.383333
# 50%           8.483333
# 75%          13.100000
# max        1409.133333
# Name: duration_min, dtype: float64

# %%
bin_edges = np.arange(1, 1409+13,13)

# Try experimenting with dynamic bin edges

g = sb.FacetGrid(data = df, col = 'start_time_dayofweek', col_wrap=3, sharey=False)
g.map(plt.hist, 'duration_min', bins = bin_edges);
g.add_legend();

# %% [markdown]
# **Observation**
#
# - Thursday has the highest trip duration over the days of the week.

# %% [markdown]
# **Resources:**
#
# - Udacity classroom, Lesson 4: Bivariate Exploration of Data, 11.Faceting.
#
# - Use the documentation [Website](https://seaborn.pydata.org/generated/seaborn.FacetGrid.html), Use **seaborn.FacetGrid()** method to Multi-plot grid for plotting conditional relationships.
#
# - Use the documentation [Website](https://www.geeksforgeeks.org/python-seaborn-facetgrid-method/), Python – **seaborn.FacetGrid() method**.

# %% [markdown]
# **Conclusion**
#
#
# **Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?**
#
# - Trip Duration is so dependendable on the age of the member, when the age between 20 to 45, the trip duration for younger ages is higher than the older ages.
# - The higher percentage of customer rides longer trips than subscriber although number of subscriber riders are higher than customer.
# - Thursday has the highest trip duration over the days of the week.
#
# **Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?**
#
# I thought that variables which are user type and gender values having higher value to get higher trip duration but it is the opposite. For gender, value of male members is very high but it got lower trip duration. For user type, value of subscriber members is very high but it got lower trip duration then customer.

# %% [markdown]
# <h3><center> Multivariate Exploration</center></h3>

# %% [markdown]
# **There are four major cases to consider when we want to plot three variables together:**
#
# - three numeric variables
# - two numeric variables and one categorical variable
# - one numeric variable and two categorical variables
# - three categorical variables

# %% [markdown]
# **Encoding via Size**
#
# - Point size is a good encoding for numeric variables. Usually, we want the numeric values to be proportional to the area of the point markers; this is the default functionality of the "s" parameter in scatter. (You need to refer to "s" through a dictionary assigned to the "scatter_kws" parameter when working with regplot.)
#
# - While the creation of the plot is easier with size, we need to put in extra leg work to create a legend. Since, as noted above, legend will only create one legend entry per plot function call, we need to create additional dummy scatter objects with reference sizes to create the plot. The color is fixed so that all of the legend entries have the same color, and two arguments are provided to the legend function: the list of plotting objects to depict in the legend, and their labels.
#
# - The size encoding for the third numeric variable ("num_var3") shows that its values are largest in the 'middle' of the distribution of values, and smaller on the upper and bottom edges. It is also clear that size is much less precise an encoding than position, so it is better used to make general, qualitative judgments than precise judgments.
#
# - In the case of the example, the data was also scaled in a way that the marker sizes made sense as given. You might need to apply a scaling factor (e.g., multiplying or dividing all values by 2) or shift in order to make the size encoding interpretable. In particular, if the values in your third numeric variable include negative values, then you might want to choose a color encoding instead.

# %%
# Encoding via Size
# Use matplotlib.pyplot.scatter() function to apply a scatter plot of y vs. x with varying marker size and /or color
plt.scatter(data = df, x = 'member_age', y = 'duration_min', s = 'member_birth_year')

# dummy series for adding legend
sizes = [20, 35, 50]
base_color = sb.color_palette()[0]
legend_obj = []
for s in sizes:
    legend_obj.append(plt.scatter([], [], s = s, color = base_color))
plt.legend(legend_obj, sizes)
# Out:
# C:\Users\hp\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# **Observation**
#
# - The data points are just all over the place.

# %% [markdown]
# **Resources:**
#
# - Udacity classroom, Lesson 5: Multivariate Exploration of Data, 2.Non-Positional Encoding For Third Variables.

# %% [markdown]
# **Faceting for Multivariate Data**

# %%
g = sb.FacetGrid(data = df, col = 'user_type', size = 8)
g.map(sb.boxplot, 'member_gender', 'duration_min')
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\axisgrid.py:645: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
g = sb.FacetGrid(data = df, col = 'member_gender', row = 'user_type', size = 2.5,margin_titles = True)
g.map(plt.scatter, 'duration_min', 'member_age');
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# **Resources:**
#
# - Udacity classroom, Lesson 5: Multivariate Exploration of Data, 5.Faceting in Two Directions.

# %% [markdown]
# **Plot Matrices**
#
# By default, PairGrid only expects to depict numeric variables; a typical invocation of PairGrid plots the same variables on the horizontal and vertical axes. On the diagonals, where the row and column variables match, a histogram is plotted. Off the diagonals, a scatterplot between the two variables is created.
#
# Use seaborn.PairGrid() functionSubplot grid for plotting pairwise relationships in a dataset.

# %%
g = sb.PairGrid(data = df, vars = ['duration_min', 'start_time_hour', 'start_time_dayofweek'])
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)

# %%
g = sb.PairGrid(data = df, x_vars = ['duration_min', 'member_age', 'member_birth_year'],
                y_vars = ['user_type','member_gender'])
g.map(sb.violinplot, inner = 'quartile')

# %% [markdown]
# **Correlation Matrices**
#
# For numeric variables, it can be useful to create a correlation matrix as part of your exploration. While it's true that the .corr function is perfectly fine for computing and returning a matrix of correlation coefficients, it's not too much trouble to plot the matrix as a heat map to make it easier to see the strength of the relationships.

# %%
# Use matplotlib.figure() function to control the default spacing of the subplots and the top level container of the subplots,
# and the top level container for all plot elements.
plt.figure(figsize=[ 11.69, 8.27]);
plt.title('Plotting Heatmap of Correlation Matrix');
sb.heatmap(df.corr(), annot = True, fmt = '.2f', cmap = 'vlag_r', center = 0);

# %% [markdown]
# **Observation**
#
# - The blue color with a positive number means positive correlation between the two variables, however, the red color with minus number means negative correlation between the two variables. The stronger the color, the larger the correlation magnitude.
#
# - Start Station Latitute has the highest positive correlation with End Station Latitude.
# - Start Station Longitude has the highest positive correlation with End Station Longitude.
# - Duration Minutes has the highest positive correlation with Duration Seconds.
#
# - Start Station Latitute has the highest negative correlation with End Station Longitude, followed by Start Station Longitude.
# - Start Station Longitude has the highest negative correlation with End Station Latitude, followed by Start Station Latitude.

# %% [markdown]
# **Resources:**
#
# - Udacity classroom, Lesson 5: Multivariate Exploration of Data, 8.Plot Matrices.

# %% [markdown]
# #### Conclusion

# %% [markdown]
# **Talk about some of the relationships you observed in this part of the investigation. Were there features that strengthened each other in terms of looking at your feature(s) of interest?**
#
# - There is no strong relationship among The features I investigated.
#
# **Were there any interesting or surprising interactions between features?**
#
# - Most 'Customer' and 'Subscribers' bikers are male.
# - An 8:00 AM and 5:00 PM have the highest customer and sunscriber bikers across seven days, twenty-four hours.
# - Thursday has the most 'Subscriber' and 'Customer' bikers compare to other days.
# - There are more younger bikers (age < 40) across 7 days and 24 hours.

# %% [markdown]
# **Summary of findings:**
#
# - From the start time hour, the time 8:00 AM and 5:00 PM are the two peak hours which have most bikers.
# - From the days of the week, Tuesday has the most bikers, compared to other days.
# - Trip duration is mostly centered on values which are less than 2000 seconds with peak around 600 seconds.
# - It seems to be that the distribution of both start stations and end stations are same.
# - The most bikers are between 25 to 40 years old.
# - There are 153,736 subscribers and 16,256 customers as user types, which representing 90% and 10% repectively.
# - In member gender, there are 126,311 male, 40,098 female, and 3,583 other, which representing 74%, 24%, 2% respectively.
# - An 8:00 AM and 5:00 PM have the highest customer and sunscriber bikers across seven days, twenty-four hours.
# - Thursday has the most 'Subscriber' and 'Customer' bikers compare to other days.
# - Most 'Customer' and 'Subscribers' bikers are male.
# - Thursday, 5:00 PM has the highest biker counts across the seven days, and twenty-four hours.
# - The weekends (Saturdays and Sundays) are the highest duration trip over the days of the week.
